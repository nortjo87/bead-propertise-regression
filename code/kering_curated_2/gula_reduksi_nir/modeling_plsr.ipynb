# %%
import pickle
import sys
sys.path.append('../../../tools')
from nipals import pls_NIPALS

# Add the 'tools' directory to the system path

# Import the nipals module

# %%
import os
import pandas as pd
import joblib

# Path ke folder data
data_dir = '../../../prepossed_curated_data_2/kering/nir/gula_reduksi'

# Membaca semua file CSV di folder
files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# Membuat DataFrame untuk setiap file
for file in files:
    df_name = file.split('.')[0]  # Nama DataFrame berdasarkan nama file
    globals()[df_name] = pd.read_csv(os.path.join(data_dir, file))

# Verifikasi jumlah DataFrame yang dibuat
print(f"Total DataFrame yang dibuat: {len(files)}")
# Out:
# Total DataFrame yang dibuat: 22

# %%
LVs_max_norm, Beta_max_norm, eps_max_norm, R2C_max_norm, SEC_max_norm, R2CV_max_norm, SECV_max_norm, R2P_max_norm, SEP_max_norm, RPD_max_norm, C_Y_Value_max_norm, V_Y_Prediction1_max_norm,V_Y_Value_max_norm,model_max_norm=pls_NIPALS(cal_max_norm.drop(columns='Gula Reduksi'),cal_max_norm['Gula Reduksi'], val_max_norm.drop(columns='Gula Reduksi'), val_max_norm['Gula Reduksi'])
max_norm=[R2C_max_norm, SEC_max_norm, R2CV_max_norm, SECV_max_norm, R2P_max_norm, SEP_max_norm, RPD_max_norm]
with open('./model/model_max_norm.pkl', 'wb') as f:
    pickle.dump(model_max_norm, f)
# Out:
# 100% Processing LVs...

# %%
LVs_mean_norm, Beta_mean_norm, eps_mean_norm, R2C_mean_norm, SEC_mean_norm, R2CV_mean_norm, SECV_mean_norm, R2P_mean_norm, SEP_mean_norm, RPD_mean_norm, C_Y_Value_mean_norm, V_Y_Prediction1_mean_norm,V_Y_Value_mean_norm,model_mean_norm=pls_NIPALS(cal_mean_norm.drop(columns='Gula Reduksi'),cal_mean_norm['Gula Reduksi'], val_mean_norm.drop(columns='Gula Reduksi'), val_mean_norm['Gula Reduksi'])
mean_norm=[R2C_mean_norm, SEC_mean_norm, R2CV_mean_norm, SECV_mean_norm, R2P_mean_norm, SEP_mean_norm, RPD_mean_norm]
with open('./model/model_mean_norm.pkl', 'wb') as f:
    pickle.dump(model_mean_norm, f)
# Out:
# 100% Processing LVs...

# %%
LVs_msc, Beta_msc, eps_msc, R2C_msc, SEC_msc, R2CV_msc, SECV_msc, R2P_msc, SEP_msc, RPD_msc, C_Y_Value_msc, V_Y_Prediction1_msc,V_Y_Value_msc,model_msc=pls_NIPALS(cal_msc.drop(columns='Gula Reduksi'),cal_msc['Gula Reduksi'], val_msc.drop(columns='Gula Reduksi'), val_msc['Gula Reduksi'])
msc=[R2C_msc, SEC_msc, R2CV_msc, SECV_msc, R2P_msc, SEP_msc,RPD_msc]
with open('./model/model_msc.pkl', 'wb') as f:
    pickle.dump(model_msc, f)
# Out:
# 100% Processing LVs...

# %%
LVs_range_norm, Beta_range_norm, eps_range_norm, R2C_range_norm, SEC_range_norm, R2CV_range_norm, SECV_range_norm, R2P_range_norm, SEP_range_norm, RPD_range_norm, C_Y_Value_range_norm, V_Y_Prediction1_range_norm,V_Y_Value_range_norm,model_range_norm=pls_NIPALS(cal_range_norm.drop(columns='Gula Reduksi'),cal_range_norm['Gula Reduksi'], val_range_norm.drop(columns='Gula Reduksi'), val_range_norm['Gula Reduksi'],lv=15,ns=10)
range_norm=[R2C_range_norm, SEC_range_norm, R2CV_range_norm, SECV_range_norm, R2P_range_norm, SEP_range_norm, RPD_range_norm]
with open('./model/model_range_norm.pkl', 'wb') as f:
    pickle.dump(model_range_norm, f)
# Out:
# 100% Processing LVs...

# %%
LVs_sg1, Beta_sg1, eps_sg1, R2C_sg1, SEC_sg1, R2CV_sg1, SECV_sg1, R2P_sg1, SEP_sg1, RPD_sg1, C_Y_Value_sg1, V_Y_Prediction1_sg1,V_Y_Value_sg1,model_sg1=pls_NIPALS(cal_sg1.drop(columns='Gula Reduksi'),cal_sg1['Gula Reduksi'], val_sg1.drop(columns='Gula Reduksi'), val_sg1['Gula Reduksi'])
sg1=[R2C_sg1, SEC_sg1, R2CV_sg1, SECV_sg1, R2P_sg1, SEP_sg1,RPD_sg1]
with open('./model/model_sg1.pkl', 'wb') as f:
    pickle.dump(model_sg1, f)
# Out:
# 100% Processing LVs...

# %%
LVs_sg2, Beta_sg2, eps_sg2, R2C_sg2, SEC_sg2, R2CV_sg2, SECV_sg2, R2P_sg2, SEP_sg2, RPD_sg2, C_Y_Value_sg2, V_Y_Prediction1_sg2,V_Y_Value_sg2,model_sg2=pls_NIPALS(cal_sg2.drop(columns='Gula Reduksi'),cal_sg2['Gula Reduksi'], val_sg2.drop(columns='Gula Reduksi'), val_sg2['Gula Reduksi'])
sg2=[R2C_sg2, SEC_sg2, R2CV_sg2, SECV_sg2, R2P_sg2, SEP_sg2,RPD_sg2]
with open('./model/model_sg2.pkl', 'wb') as f:
    pickle.dump(model_sg2, f)
# Out:
# 100% Processing LVs...

# %%
LVs_snv, Beta_snv, eps_snv, R2C_snv, SEC_snv, R2CV_snv, SECV_snv, R2P_snv, SEP_snv, RPD_snv, C_Y_Value_snv, V_Y_Prediction1_snv,V_Y_Value_snv,model_snv=pls_NIPALS(cal_snv.drop(columns='Gula Reduksi'),cal_snv['Gula Reduksi'], val_snv.drop(columns='Gula Reduksi'), val_snv['Gula Reduksi'],lv=15,ns=10)
snv=[R2C_snv, SEC_snv, R2CV_snv, SECV_snv, R2P_snv, SEP_snv,RPD_snv]
with open('./model/model_snv.pkl', 'wb') as f:
    pickle.dump(model_snv, f)
# Out:
# 100% Processing LVs...

# %%
LVs_fd1, Beta_fd1, eps_fd1, R2C_fd1, SEC_fd1, R2CV_fd1, SECV_fd1, R2P_fd1, SEP_fd1, RPD_fd1, C_Y_Value_fd1, V_Y_Prediction1_fd1,V_Y_Value_fd1,model_fd1=pls_NIPALS(cal_fd1.drop(columns='Gula Reduksi'),cal_fd1['Gula Reduksi'], val_fd1.drop(columns='Gula Reduksi'), val_fd1['Gula Reduksi'],lv=15,ns=10)
smoothing_fd1=[R2C_fd1, SEC_fd1, R2CV_fd1, SECV_fd1, R2P_fd1, SEP_fd1,RPD_fd1]
with open('./model/model_fd1.pkl', 'wb') as f:
    pickle.dump(model_fd1, f)
# Out:
# 100% Processing LVs...

# %%
LVs_fd2, Beta_fd2, eps_fd2, R2C_fd2, SEC_fd2, R2CV_fd2, SECV_fd2, R2P_fd2, SEP_fd2, RPD_fd2, C_Y_Value_fd2, V_Y_Prediction1_fd2,V_Y_Value_fd2,model_fd2=pls_NIPALS(cal_fd2.drop(columns='Gula Reduksi'),cal_fd2['Gula Reduksi'], val_fd2.drop(columns='Gula Reduksi'), val_fd2['Gula Reduksi'],lv=15,ns=10)
smoothing_fd2=[R2C_fd2, SEC_fd2, R2CV_fd2, SECV_fd2, R2P_fd2, SEP_fd2,RPD_fd2]
with open('./model/model_fd2.pkl', 'wb') as f:
    pickle.dump(model_fd2, f)
# Out:
# 100% Processing LVs...

# %%
LVs_ori, Beta_ori, eps_ori, R2C_ori, SEC_ori, R2CV_ori, SECV_ori, R2P_ori, SEP_ori, RPD_ori, C_Y_Value_ori, V_Y_Prediction1_ori,V_Y_Value_ori,model_ori=pls_NIPALS(cal_ori.drop(columns='Gula Reduksi'),cal_ori['Gula Reduksi'], val_ori.drop(columns='Gula Reduksi'), val_ori['Gula Reduksi'])
smoothing_ori=[R2C_ori, SEC_ori, R2CV_ori, SECV_ori, R2P_ori, SEP_ori,RPD_ori]
os.makedirs('./model', exist_ok=True)
with open('./model/model_ori.pkl', 'wb') as f:
    pickle.dump(model_ori, f)
# Out:
# 100% Processing LVs...

# %%
# Gabungkan hasil evaluasi ke dalam satu DataFrame
results = pd.DataFrame({
    'Preprocessing': [
        'max_norm', 'mean_norm', 'msc', 'range_norm', 'sg1', 'sg2', 'snv', 'fd1', 'fd2','ori'
    ],
    'R2C': [
        max_norm[0], mean_norm[0], msc[0], range_norm[0], sg1[0], sg2[0], snv[0], smoothing_fd1[0], smoothing_fd2[0],smoothing_ori[0]
    ],
    'SEC': [
        max_norm[1], mean_norm[1], msc[1], range_norm[1], sg1[1], sg2[1], snv[1], smoothing_fd1[1], smoothing_fd2[1],smoothing_ori[1]
    ],
    'R2CV': [
        max_norm[2], mean_norm[2], msc[2], range_norm[2], sg1[2], sg2[2], snv[2], smoothing_fd1[2], smoothing_fd2[2],smoothing_ori[2]
    ],
    'SECV': [
        max_norm[3], mean_norm[3], msc[3], range_norm[3], sg1[3], sg2[3], snv[3], smoothing_fd1[3], smoothing_fd2[3],smoothing_ori[3]
    ],
    'R2P': [
        max_norm[4], mean_norm[4], msc[4], range_norm[4], sg1[4], sg2[4], snv[4], smoothing_fd1[4], smoothing_fd2[4],smoothing_ori[4]
    ],
    'SEP': [
        max_norm[5], mean_norm[5], msc[5], range_norm[5], sg1[5], sg2[5], snv[5], smoothing_fd1[5], smoothing_fd2[5],smoothing_ori[5]
    ],
    'RDP': [
        max_norm[6], mean_norm[6], msc[6], range_norm[6], sg1[6], sg2[6], snv[6], smoothing_fd1[6], smoothing_fd2[6],smoothing_ori[6]
    ]
})

# Simpan ke file CSV
results.to_csv('pls_results_summary.csv', index=False)

# %%
os.makedirs('beta_coef', exist_ok=True)
wavelengths = [float(col) for col in cal_ori.columns if col != 'Gula Reduksi']

beta_arrays = {
    'max_norm': Beta_max_norm,
    'mean_norm': Beta_mean_norm,
    'msc': Beta_msc,
    'range_norm': Beta_range_norm,
    'sg1': Beta_sg1,
    'sg2': Beta_sg2,
    'snv': Beta_snv,
    'fd1': Beta_fd1,
    'fd2': Beta_fd2,
    'ori': Beta_ori
}

for name, beta_val in beta_arrays.items():
    beta = beta_val.flatten()
    df = pd.DataFrame({'Wavelength': wavelengths, 'Beta': beta})
    df.to_csv(f'beta_coef/beta_{name}.csv', index=False)

# %%
import matplotlib.pyplot as plt
# Plot Beta coefficients for each preprocessing method
beta_dict = {
    'max_norm': Beta_max_norm,
    'mean_norm': Beta_mean_norm,
    'msc': Beta_msc,
    'range_norm': Beta_range_norm,
    'sg1': Beta_sg1,
    'sg2': Beta_sg2,
    'snv': Beta_snv,
    'smoothing_fd1': Beta_fd1,
    'smoothing_fd2': Beta_fd2,
    'ori': Beta_ori
}


wl = [float(col) for col in cal_ori.columns if col != 'Gula Reduksi']


for name, beta_val in beta_dict.items():
    if hasattr(beta_val, 'flatten'):
        beta = beta_val.flatten()
    elif isinstance(beta_val, (list, tuple)) and len(beta_val) == 1:
        beta = beta_val[0]
    else:
        beta = beta_val

    plt.figure(figsize=(10, 5))
    plt.plot(wl, beta)
    plt.xlabel('Wavelength (nm)')
    plt.ylabel(f'intensity (%)')
    plt.title(f'Beta Coefficients vs Wavelength ({name})')
    plt.show()
