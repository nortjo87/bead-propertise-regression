# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease
# Out:
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
import os
import pandas as pd

# Path ke folder data
data_dir = '../prepossed_data/nir/kadar_air'

# Membaca semua file CSV di folder
files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# Membuat DataFrame untuk setiap file
for file in files:
    df_name = file.split('.')[0]  # Nama DataFrame berdasarkan nama file
    globals()[df_name] = pd.read_csv(os.path.join(data_dir, file))

# Verifikasi jumlah DataFrame yang dibuat
print(f"Total DataFrame yang dibuat: {len(files)}")
# Out:
# Total DataFrame yang dibuat: 16

# %%
cal_max_norm
# Out:
#       954.165   960.187   966.207   972.224   978.239   984.252   990.262  \
# 0    0.996924  0.999316  0.990602  0.986842  0.981716  0.982057  0.979152
# 1    0.983973  0.987464  0.979848  0.976674  0.972390  0.973500  0.970962
# 2    0.997011  1.000000  0.990038  0.985854  0.980474  0.981271  0.977685
# 3    0.972888  0.974329  0.966601  0.963327  0.959790  0.960576  0.959005
# 4    0.972416  0.973628  0.965293  0.961655  0.958169  0.959382  0.958472
# ..        ...       ...       ...       ...       ...       ...       ...
# 479  0.977393  0.977845  0.971364  0.968199  0.965637  0.966240  0.965335
# 480  0.998626  0.997767  0.990383  0.986433  0.983342  0.983685  0.982655
# 481  0.998786  1.000000  0.992198  0.988558  0.984223  0.984050  0.981449
# 482  0.987406  0.986517  0.980886  0.977626  0.975256  0.975256  0.974959
# 483  0.988191  0.990080  0.981893  0.978271  0.974177  0.974965  0.972918
#
#        996.27  1002.275  1008.278  ...  1654.273  1660.015  1665.755  \
# 0    0.976418  0.983937  0.982570  ...  0.490772  0.494874  0.492652
# 1    0.968264  0.976515  0.975563  ...  0.501904  0.506189  0.503650
# 2    0.974298  0.982467  0.980673  ...  0.456665  0.460849  0.456864
# 3    0.957564  0.966077  0.966863  ...  0.513818  0.521284  0.524427
# 4    0.957866  0.966202  0.967263  ...  0.469233  0.473931  0.472871
# ..        ...       ...       ...  ...       ...       ...       ...
# 479  0.964431  0.969857  0.970610  ...  0.491786  0.491635  0.486963
# 480  0.981281  0.984029  0.982827  ...  0.524644  0.525674  0.523957
# 481  0.978675  0.984050  0.982490  ...  0.551491  0.554438  0.552358
# 482  0.974959  0.978071  0.978664  ...  0.509557  0.508223  0.504223
# 483  0.970556  0.977641  0.976854  ...  0.489214  0.493623  0.492206
#
#      1671.492  1677.227   1682.96  1688.691  1694.419  1700.144  kadar air
# 0    0.497437  0.507861  0.531442  0.553315  0.578093  0.593985      32.45
# 1    0.509045  0.520628  0.545858  0.567122  0.589654  0.602666      28.44
# 2    0.459454  0.467225  0.488544  0.507073  0.529787  0.545328      32.45
# 3    0.534774  0.551932  0.580878  0.607728  0.634185  0.649771      37.06
# 4    0.477266  0.486511  0.506820  0.524704  0.544559  0.556835      39.98
# ..        ...       ...       ...       ...       ...       ...        ...
# 479  0.486209  0.488772  0.498417  0.504748  0.511680  0.514996      29.58
# 480  0.526018  0.531685  0.543878  0.554697  0.567233  0.574618      30.21
# 481  0.556519  0.565014  0.584258  0.601075  0.619279  0.630201      32.57
# 482  0.502148  0.501852  0.504223  0.504519  0.505408  0.505853      40.29
# 483  0.497874  0.508739  0.531885  0.551567  0.572981  0.585262      30.21
#
# [484 rows x 129 columns]

# %%
X_train = cal_max_norm.drop(columns=['kadar air'])
y_train = cal_max_norm['kadar air']
X_test = val_max_norm.drop(columns=['kadar air'])
y_test = val_max_norm['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling="minmax"), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, n_jobs=-1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Train Score: 0.8073670997343317
# Test Score: 0.771392650786191
# CV Accuracy Scores: [0.72403553 0.88228873 0.68404172 0.71749593 0.67233278 0.74665844
#  0.74855781 0.80804931 0.74616811 0.80034941]
# Mean CV Accuracy: 0.7529977770626197

# %%
X_train = cal_mean_norm.drop(columns=['kadar air'])
y_train = cal_mean_norm['kadar air']
X_test = val_mean_norm.drop(columns=['kadar air'])
y_test = val_mean_norm['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling="minmax"), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.774544985600302
# Test Score: 0.7721189608952506
# CV Accuracy Scores: [0.58441484 0.86971035 0.63165858 0.7299697  0.70106331 0.67208614
#  0.6468558  0.80122143 0.67229571 0.7447275 ]
# Mean CV Accuracy: 0.7054003364492287
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   16.1s finished

# %%
X_train = cal_msc.drop(columns=['kadar air'])
y_train = cal_msc['kadar air']
X_test = val_msc.drop(columns=['kadar air'])
y_test = val_msc['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.8880225606270804
# Test Score: 0.8297901493988638
# CV Accuracy Scores: [0.7213606  0.85233038 0.78385868 0.79234139 0.83231571 0.81634702
#  0.72478561 0.88776564 0.70615515 0.77225863]
# Mean CV Accuracy: 0.7889518816759622
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   15.5s finished

# %%
X_train = cal_range_norm.drop(columns=['kadar air'])
y_train = cal_range_norm['kadar air']
X_test = val_range_norm.drop(columns=['kadar air'])
y_test = val_range_norm['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.7486191165312269
# Test Score: 0.7643841527414947
# CV Accuracy Scores: [0.68118896 0.79216555 0.60611037 0.55575622 0.58271426 0.61897975
#  0.60433031 0.78479954 0.66191996 0.58786663]
# Mean CV Accuracy: 0.6475831548720687
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   15.7s finished

# %%
X_train = cal_sg1.drop(columns=['kadar air'])
y_train = cal_sg1['kadar air']
X_test = val_sg1.drop(columns=['kadar air'])
y_test = val_sg1['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.8330951018919348
# Test Score: 0.7899378617916394
# CV Accuracy Scores: [0.82934865 0.91685743 0.69718602 0.78685418 0.74735901 0.79367091
#  0.747563   0.87111956 0.748932   0.81331442]
# Mean CV Accuracy: 0.795220520095942
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   16.0s finished

# %%
X_train = cal_sg2.drop(columns=['kadar air'])
y_train = cal_sg2['kadar air']
X_test = val_sg2.drop(columns=['kadar air'])
y_test = val_sg2['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.9184856902848624
# Test Score: 0.8650344613820657
# CV Accuracy Scores: [0.87704314 0.9453698  0.74696544 0.78908267 0.80785692 0.84648972
#  0.8869062  0.91172607 0.81894877 0.84424299]
# Mean CV Accuracy: 0.8474631718157338
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   15.8s finished

# %%
X_train = cal_smoothing_mean.drop(columns=['kadar air'])
y_train = cal_smoothing_mean['kadar air']
X_test = val_smoothing_mean.drop(columns=['kadar air'])
y_test = val_smoothing_mean['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.7918721508539885
# Test Score: 0.6860858676633586
# CV Accuracy Scores: [0.54079844 0.68559367 0.62636277 0.59988617 0.54496257 0.47143059
#  0.22004529 0.69243572 0.54014198 0.59815951]
# Mean CV Accuracy: 0.5519816713818146
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   16.6s finished

# %%
X_train = cal_snv.drop(columns=['kadar air'])
y_train = cal_snv['kadar air']
X_test = val_snv.drop(columns=['kadar air'])
y_test = val_snv['kadar air']

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])
from sklearn.svm import SVR
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

model = GridSearchCV(pipeline, gsp.svm_params, cv=10, scoring='r2', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, y_train, cv=10, scoring='r2', n_jobs=-1, verbose=1)
print("CV Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# c:\Users\snyil\miniconda3\envs\envMLjcop\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Train Score: 0.8362069012189621
# Test Score: 0.8088435024422257
# CV Accuracy Scores: [0.75790642 0.88632363 0.73315391 0.80092894 0.81694135 0.66772918
#  0.6909342  0.8438759  0.736855   0.80367989]
# Mean CV Accuracy: 0.7738328418273971
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   14.8s finished
